# %% [markdown]
# # Data I/O Exercies

# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
f = open('messy_data.dat', 'w')
import random
for i in range(100):
    for j in range(5):
        f.write(' ' * random.randint(0, 6))
        f.write('%0*.*g' % (random.randint(8, 12),
                            random.randint(5, 10),
                            100 * random.random()))
        if j != 4:
            f.write(',')
    f.write('\n')
f.close()

# %%
f=open('messy_data.dat')
print f.readlines()
f.close
# Out:
# ['40.781109,    7.300636436,0026.386,    000084.97168, 00000041.035\n', '   12.42779811,    83.1782773,00050.256,   00003.68456,    003.11811426\n', ' 68.2795644,   0.1622238,   0046.276,    0000055.163,  60.90350161\n', '97.409271,      068.494286,   43.52822752,      00088.577415,      000047.796\n', ' 00096.45645,    0045.0194,  0029.266,  76.278774,  00088.0829\n', ' 000014.129,   98.0887807,   7.806716681,   015.7317,  025.152122\n', '  000028.941,    54.5213141,   046.7817456,     00036.35908, 61.7983934\n', '      00086.15216,  88.30428813,      045.95095777,     48.88296,   0000.5178131\n', ' 71.601998,    00073.706,     0000087.4717, 0030.793,    82.35795678\n', '    044.8271768,  000077.93018,      008.0685,00073.12527,   54.75054\n', ' 08.45729,  007.171761, 0044.3504045,   000015.961, 2.0802216\n', '  5.9306834,      0058.0097251,      0000049.3182,005.2535773,   041.36367966\n', '    32.6402605,     0064.5210324,    044.11242,    00058.785503,  000073.727\n', '  21.35299
# ...

# %%
Data1 = np.loadtxt('messy_data.dat', unpack=True, delimiter= ',', usecols=[0,2])
print Data1
# Out:
# [[ 40.781109    12.42779811  68.2795644   97.409271    96.45645     14.129
#    28.941       86.15216     71.601998    44.8271768    8.45729      5.9306834
#    32.6402605   21.3529992   20.543914    17.584398    27.931       45.04881501
#    74.2135      56.5439      19.199       73.330771    54.409826
#     2.82997194  21.12783893  44.95364931  41.421       24.997       38.45763
#    68.972381    92.282203    39.83395     36.732574    24.967765    15.3374
#    62.8754888   30.648954    64.5302      55.786095    31.337191    65.03
#    38.5142      57.609874    85.0856      93.3255316   54.1990191
#     6.65382262   4.611606    13.34451059  82.296       87.75416     20.0959326
#    16.3293      64.45573     74.765393    46.4868      34.4959      78.3035628
#    38.895764    66.97125     91.569       27.909       45.741558    52.9205
#    79.91258      0.2156464   61.28841371  76.891       42.657341    49.4271
#    59.453       26.5588      68.5400665   58.2945296   32.802273
# ...

# %%
savetxt('clean_data.dat', Data1, fmt=('%4.3f'))

# %%
# !more clean_data.dat
# Out:
# 40.781 12.428 68.280 97.409 96.456 14.129 28.941 86.152 71.602 44.827 8.457 5.931 32.640 21.353 20.544 17.584 27.931 45.049 74.213 56.544 19.199 73.331 54.410 2.830 21.128 44.954 41.421 24.997 38.458 68.972 92.282 39.834 36.733 24.968 15.337 62.875 30.649 64.530 55.786 31.337 65.030 38.514 57.610 85.086 93.326 54.199 6.654 4.612 13.345 82.296 87.754 20.096 16.329 64.456 74.765 46.487 34.496 78.304 38.896 66.971 91.569 27.909 45.742 52.920 79.913 0.216 61.288 76.891 42.657 49.427 59.453 26.559 68.540 58.295 32.802 89.580 35.713 59.842 22.178 15.137 29.672 68.187 33.768 3.686 90.561 23.581 24.246 8.905 76.703 69.239 70.134 82.593 50.382 66.957 41.013 93.533 86.362 24.941 62.367 77.995
# ...

# %%
DataIn = np.loadtxt('clean_data.dat')
DataIn.reshape(50L, 4L)
# Out:
# array([[ 40.781,  12.428,  68.28 ,  97.409],
#        [ 96.456,  14.129,  28.941,  86.152],
#        [ 71.602,  44.827,   8.457,   5.931],
#        [ 32.64 ,  21.353,  20.544,  17.584],
#        [ 27.931,  45.049,  74.213,  56.544],
#        [ 19.199,  73.331,  54.41 ,   2.83 ],
#        [ 21.128,  44.954,  41.421,  24.997],
#        [ 38.458,  68.972,  92.282,  39.834],
#        [ 36.733,  24.968,  15.337,  62.875],
#        [ 30.649,  64.53 ,  55.786,  31.337],
#        [ 65.03 ,  38.514,  57.61 ,  85.086],
#        [ 93.326,  54.199,   6.654,   4.612],
#        [ 13.345,  82.296,  87.754,  20.096],
#        [ 16.329,  64.456,  74.765,  46.487],
#        [ 34.496,  78.304,  38.896,  66.971],
#        [ 91.569,  27.909,  45.742,  52.92 ],
#        [ 79.913,   0.216,  61.288,  76.891],
#        [ 42.657,  49.427,  59.453,  26.559],
#        [ 68.54 ,  58.295,  32.802,  89.58 ],
#        [ 35.713,  59.842,  22.178,  15.137],
#        [ 29.672,  68.187,  33.768,   3.686],
# ...

# %%
savetxt('clean_data.dat', DataIn, fmt='%4.1f')
# !more clean_data.dat
# Out:
# 40.8 12.4 68.3 97.4 96.5 14.1 28.9 86.2 71.6 44.8  8.5  5.9 32.6 21.4 20.5 17.6 27.9 45.0 74.2 56.5 19.2 73.3 54.4  2.8 21.1 45.0 41.4 25.0 38.5 69.0 92.3 39.8 36.7 25.0 15.3 62.9 30.6 64.5 55.8 31.3 65.0 38.5 57.6 85.1 93.3 54.2  6.7  4.6 13.3 82.3 87.8 20.1 16.3 64.5 74.8 46.5 34.5 78.3 38.9 67.0 91.6 27.9 45.7 52.9 79.9  0.2 61.3 76.9 42.7 49.4 59.5 26.6 68.5 58.3 32.8 89.6 35.7 59.8 22.2 15.1 29.7 68.2 33.8  3.7 90.6 23.6 24.2  8.9 76.7 69.2 70.1 82.6 50.4 67.0 41.0 93.5 86.4 24.9 62.4 78.0
# ...
