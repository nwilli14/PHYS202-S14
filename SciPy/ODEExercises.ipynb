# %% [markdown]
# # ODE Exercises

# %% [markdown]
# ## Question 1

# %% [markdown]
# ###### (a) See what happens to the period of the pendulum as you change the initial angle of release. Plot θ vs t for 5 different initial angles, θ0 , spanning 0 to π. (i.e. 0, π/4 , π/2 , 3π/4 , and π ). Put them all on the same plot. What happens to the period of the pendulum as the initial angle increases from π/4 to 3π/4? What happens to the trajectory when the initial angle is 0 and π ?

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
g = 9.8 #m/s^2
ell = 0.5 #m
th0= [0, pi/4, pi/2, 3*pi/4, pi] 

def deriv(theta_current,t): # return derivatives of the array theta
    g = 9.8 #m/s^s
    ell = 0.5 #m
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta= omega
    domega= -(g/ell)*np.sin(theta)
    return np.array([dtheta, domega])

t = np.arange(0.,10.+0.01,0.01)

omega0 = 0. #starting from rest, omega = 0

theta_init0 = np.array([th0[0], omega0])
theta0 = odeint(deriv, theta_init0, t)

theta_init1 = np.array([th0[1], omega0])
theta1 = odeint(deriv, theta_init1, t)

theta_init2 = np.array([th0[2], omega0])
theta2 = odeint(deriv, theta_init2, t)

theta_init3 = np.array([th0[3], omega0])
theta3 = odeint(deriv, theta_init3, t)

theta_init4 = np.array([th0[4], omega0])
theta4 = odeint(deriv, theta_init4, t)

# %%
plt.plot(t,theta0[:,0],'r',label='Initial Angle = 0')
plt.plot(t,theta1[:,0],'b',label='Initial Angle = $\pi$/4')
plt.plot(t,theta2[:,0],'g',label='Initial Angle = $\pi$/2')
plt.plot(t,theta3[:,0],'black',label='Initial Angle = 3$\pi$/4')
plt.plot(t,theta4[:,0],'purple',label='Initial Angle = $\pi$')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.grid()
plt.legend(loc="upper left", bbox_to_anchor=(1,1), fontsize=15)
plt.show()

# %% [markdown]
# #### What happens to the period of the pendulum as the initial angle increases from π/4 to 3π/4?

# %% [markdown]
# The period is increased.

# %% [markdown]
# #### What happens to the trajectory when the initial angle is 0 and π ?

# %% [markdown]
# When the th0 is 0 the pendulum does not move.
#
# When the th0 is $\pi$, the pedulum is a straight line due to the fact that the pendulum is droped
# straight downso it has no side momentum.

# %% [markdown]
# ###### (b) Make plots of θ vs. t, ω vs. t, and ω vs. θ (the so-called "phase plot") for θ0 = 0.95π. Look carefully at their behavior. What is going on in these figures?

# %%
g = 9.8 #m/s^2
ell = 0.5 #m
th0= .95*pi
t = np.arange(0.,10.+0.01,0.01)


def deriv(theta_current,t): # return derivatives of the array theta
    g = 9.8 #m/s^s
    ell = 0.5 #m
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta= omega
    domega= -(g/ell)*np.sin(theta)
    return np.array([dtheta, domega])

omega0 = 0. 
theta_init = np.array([th0, omega0])

theta = odeint(deriv, theta_init, t)

plt.plot(t,theta[:,0],'b')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.grid()
plt.title(r'$\theta $ vs time')
plt.show()

# %%
plt.plot(t,theta[:,1],'g')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\omega $',fontsize=20)
plt.grid()
plt.title(r'$\omega$ vs time', fontsize=20)
plt.show()

# %%
plt.plot(theta[:,0],theta[:,1],'r')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\omega $',fontsize=20)
plt.grid()
plt.title(r'$\omega$ vs $\theta$',fontsize=20)
plt.show()

# %% [markdown]
# (c) For the θ0 = 0.95π case, check that energy is conserved by plotting E/m vs. t (where E/m=gℓcos(θ)+12ℓ2ω2 ).

# %%
theta = odeint(deriv, theta_init, t)
Em = g*ell*(1-np.cos(theta[:,0])) + .5*ell**2*theta[:,1]**2

plt.plot(t, Em,'r')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'Energy',fontsize=20)
plt.ylim(0,10)
plt.grid()
plt.title('Energy vs time',fontsize=20)
plt.show()

# %%
help(odeint)
# Out:
# Help on function odeint in module scipy.integrate.odepack:
#
# odeint(func, y0, t, args=(), Dfun=None, col_deriv=0, full_output=0, ml=None, mu=None, rtol=None, atol=None, tcrit=None, h0=0.0, hmax=0.0, hmin=0.0, ixpr=0, mxstep=0, mxhnil=0, mxordn=12, mxords=5, printmessg=0)
#     Integrate a system of ordinary differential equations.
#
#     Solve a system of ordinary differential equations using lsoda from the
#     FORTRAN library odepack.
#
#     Solves the initial value problem for stiff or non-stiff systems
#     of first order ode-s::
#
#         dy/dt = func(y,t0,...)
#
#     where y can be a vector.
#
#     Parameters
#     ----------
#     func : callable(y, t0, ...)
#         Computes the derivative of y at t0.
#     y0 : array
#         Initial condition on y (can be a vector).
#     t : array
#         A sequence of time points for which to solve for y.  The initial
#         value point should be the first element of this sequence.
#     args : tuple, optional
#         Extra arguments to pass to function.
#     Dfun : callable(y, t0, ...)
#         Gradient (Jacobian) of `func`.
#     col_deriv : bool, optional
#         True if `Dfun` defines derivatives down columns (faster),
#         otherwise `Dfun` should define derivatives across rows.
#     full_output : bool, optional
#         True if to return a dictionary of optional outputs as the second output
#     printmessg : bool, optional
#         Whether to print the convergence message
#
#     Returns
#     -------
#     y : array, shape (len(t), len(y0))
#         Array containing the value of y for each desired time in t,
#         with the initial value `y0` in the first row.
#     infodict : dict, only returned if full_output == True
#         Dictionary containing additional output information
#
#         =======  ============================================================
#         key      meaning
#         =======  ============================================================
#         'hu'     vector of step sizes successfully used for each time step.
#         'tcur'   vector with the value of t reached for each time step.
#                  (will always be at least as large as the input times).
#         'tolsf'  vector of tolerance scale factors, greater than 1.0,
#                  computed when a request for too much accuracy was detected.
#         'tsw'    value of t at the time of the last method switch
#                  (given for each time step)
#         'nst'    cumulative number of time steps
#         'nfe'    cumulative number of function evaluations for each time step
#         'nje'    cumulative number of jacobian evaluations for each time step
#         'nqu'    a vector of method orders for each successful step.
#         'imxer'  index of the component of largest magnitude in the
#                  weighted local error vector (e / ewt) on an error return, -1
#                  otherwise.
#         'lenrw'  the length of the double work array required.
#         'leniw'  the length of integer work array required.
#         'mused'  a vector of method indicators for each successful time step:
#                  1: adams (nonstiff), 2: bdf (stiff)
#         =======  ============================================================
#
#     Other Parameters
#     ----------------
#     ml, mu : int, optional
#         If either of these are not None or non-negative, then the
#         Jacobian is assumed to be banded.  These give the number of
#         lower and upper non-zero diagonals in this banded matrix.
#         For the banded case, `Dfun` should return a matrix whose
#         columns contain the non-zero bands (starting with the
#         lowest diagonal).  Thus, the return matrix from `Dfun` should
#         have shape ``len(y0) * (ml + mu + 1)`` when ``ml >=0`` or ``mu >=0``.
#     rtol, atol : float, optional
#         The input parameters `rtol` and `atol` determine the error
#         control performed by the solver.  The solver will control the
#         vector, e, of estimated local errors in y, according to an
#         inequality of the form ``max-norm of (e / ewt) <= 1``,
#         where ewt is a vector of positive error weights computed as
#         ``ewt = rtol * abs(y) + atol``.
#         rtol and atol can be either vectors the same length as y or scalars.
#         Defaults to 1.49012e-8.
#     tcrit : ndarray, optional
#         Vector of critical points (e.g. singularities) where integration
#         care should be taken.
#     h0 : float, (0: solver-determined), optional
#         The step size to be attempted on the first step.
#     hmax : float, (0: solver-determined), optional
#         The maximum absolute step size allowed.
#     hmin : float, (0: solver-determined), optional
#         The minimum absolute step size allowed.
#     ixpr : bool, optional
#         Whether to generate extra printing at method switches.
#     mxstep : int, (0: solver-determined), optional
#         Maximum number of (internally defined) steps allowed for each
#         integration point in t.
#     mxhnil : int, (0: solver-determined), optional
#         Maximum number of messages printed.
#     mxordn : int, (0: solver-determined), optional
#         Maximum order to be allowed for the non-stiff (Adams) method.
#     mxords : int, (0: solver-determined), optional
#         Maximum order to be allowed for the stiff (BDF) method.
#
#     See Also
#     --------
#     ode : a more object-oriented integrator based on VODE.
#     quad : for finding the area under a curve.

# %% [markdown]
# (d) Now look at what happens if we start the pendulum straight up, θ=π. Go for at least 50 s. Be sure to describe what happens numerically according to the θ vs. t, ω vs. t and E/m vs. t plots. What do you think should happen? What happens if you change the error tolerance on odeint? How does this compare to a nearly vertical pendulum: θ0=π−0.000001 ?

# %%
g = 9.8 #m/s^2
ell = 0.5 #m
th0= pi
t = np.arange(0.,50.+0.01,0.01)



omega0 = 0. 
theta_init = np.array([th0, omega0])

theta = odeint(deriv, theta_init, t)

plt.plot(t,theta[:,0],'b')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.grid()
plt.title(r'$\theta $ vs time',fontsize=20)
plt.show()

# %%
plt.plot(t,theta[:,1],'b')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\omega$',fontsize=20)
plt.grid()
plt.title(r'$\omega $ vs time',fontsize=20)
plt.show()

# %%
theta = odeint(deriv, theta_init, t, rtol=1e-8, atol=1e-8)
Em = g*ell*(1-np.cos(theta[:,0])) + .5*ell**2*theta[:,1]**2


plt.plot(t, Em,'r')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'Energy',fontsize=20)
plt.ylim(0, 10)
plt.grid()
plt.title('Energy vs time',fontsize=20)
plt.show()

# %%
g = 9.8 #m/s^2
ell = 0.5 #m
th0= pi - 0.000001
t = np.arange(0.,50.+0.01,0.01)



omega0 = 0. 
theta_init = np.array([th0, omega0])

theta = odeint(deriv, theta_init, t)

plt.plot(t,theta[:,0],'b')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.grid()
plt.title(r'$\theta $ vs time',fontsize=20)
plt.show()

# %% [markdown]
# ## Question 2

# %% [markdown]
# (a) Use Euler's method (not odeint) to solve the following first-order differential equation with given initial condition y(0) = 0.
# dydx=x+2y
# Find the value of y when x = 1, y(1), using two different step sizes: 0.25 then 0.02.

# %%
def EulerFreefall(dx):
    xmax = 2  
    nsteps = int(xmax/dx)
    x = np.zeros(nsteps)
    y = np.zeros(nsteps)
    F = x + 2*y
    
    # set initial conditions, redundant in this example
    x[0] = 0.
    y[0] = 0.

    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
        y[i+1] = y[i] + dx * (x[i]+2*y[i])
       
        
    return x,y

# %%
xe,ye = EulerFreefall(.25)

from scipy.interpolate import interp1d

interp = interp1d(xe, ye)

newx = 1
newy = interp(newx)

plt.plot(xe, ye, newx, newy, 'r+', markersize=20, markeredgewidth=3)
plt.plot(xe,ye,"g-",label='y(t)')
plt.annotate(newy, xy = (newx, newy), xytext=(1, 1))
plt.title("y'=x+2y,  dx=.25", fontsize=20)
plt.grid()
plt.show()

# %%
xe2,ye2 = EulerFreefall(.02)

from scipy.interpolate import interp1d

interp = interp1d(xe2, ye2)

newx = 1
newy = interp(newx)

plt.plot(xe2, ye2, newx, newy, 'r+', markersize=20, markeredgewidth=3)
plt.plot(xe2,ye2,"b-",label='y(t)')
plt.annotate(newy, xy = (newx, newy), xytext=(1, 2))
plt.title("y'=x+2y,  dx=.02", fontsize=20)
plt.grid()
plt.show()

# %% [markdown]
# (b) Plot the results from part (a) for the two different step sizes with the exact solution
# y=0.25e2x−0.5x−0.25
# on one plot. Include a legend. Which step size gives a more accurate result?

# %%
soln = 0.25*exp(2*xe2)-0.5*xe2-0.25
plt.plot(xe,ye,"g-",label='dx=0.25')
plt.plot(xe2,ye2,"b-",label='dx=0.02')
plt.plot(xe2, soln, "r", label='exact soln')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# (c) Now solve the same problem using Euler-Cromer and the Midpoint method for the same pair of step sizes and plot the results along with the exact solution. Then also plot the difference between the approximate numerical solutions and the exact solution. Which combination of method and step-size gives the best result?

# %%
def EulerCromerFreefall(dx):
    xmax = 2  
    nsteps = int(xmax/dx)
    x = np.zeros(nsteps)
    y = np.zeros(nsteps)
    F = x + 2*y
    
    # set initial conditions, redundant in this example
    x[0] = 0.
    y[0] = 0.

    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
        y[i+1] = y[i] + dx * (x[i+1]+2*y[i+1])
       
        
    return x,y

# %%
xe,ye = EulerCromerFreefall(.25)
xe2,ye2 = EulerCromerFreefall(.02)

soln = 0.25*exp(2*xe2)-0.5*xe2-0.25
plt.plot(xe,ye,"g-",label='dx=0.25')
plt.plot(xe2,ye2,"b-",label='dx=0.02')
plt.plot(xe2, soln, "r", label='exact soln')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
error = soln - ye2
plt.plot(xe2, error, "black", label='Euler-Cromer error of dx=0.2')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
def Midpoint(dx):
    xmax = 2  
    nsteps = int(xmax/dx)
    x = np.zeros(nsteps)
    y = np.zeros(nsteps)
    F = x + 2*y
    
    # set initial conditions, redundant in this example
    x[0] = 0.
    y[0] = 0.

    for i in range(len(x)-1):
        x[i+1] = x[i] + dx
        y[i+1] = y[i] + dx * (.5*(x[i+1]+x[i])+(y[i+1]+y[i]))
       
        
    return x,y

# %%
xe,ye = Midpoint(.25)
xe2,ye2 = Midpoint(.02)

soln = 0.25*exp(2*xe2)-0.5*xe2-0.25
plt.plot(xe,ye,"g-",label='dx=0.25')
plt.plot(xe2,ye2,"b-",label='dx=0.02')
plt.plot(xe2, soln, "r", label='exact soln')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
error = soln - ye2
plt.plot(xe2, error, "black", label='midpoint error of dx=0.2')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# ## Question 3

# %% [markdown]
# (a) Create a derivative function to solve this system of equations and use odeint to solve it for a projectile fired at an angle of 50 degrees from the horizontal at an initial speed of 30 m/s. Track the projectile's motion over the time interval of 0 to 200 seconds and let (x0,y0) = (0,0). You'll have to calculate (vx0,vy0) from the information provided. Let vter=44 m/s. Plot the trajectory of the projectile (y vs. x) to see how far it can travel in the x direction before landing.

# %%
def derivative(y,t):
    vter = 44 #m/s
    g = 9.81 #m/s^2
    vx = y[0]
    vy = y[2]
    m = 1 #kg
    
    y1 = y[3]
    x1 = y[1]
    dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
    dvydt = -g/m * (1 + vy/vter**2 * sqrt(vx**2+vy**2))
    return np.array([dvxdt, vx, dvydt, vy])

# %%
vx0 = 30*np.cos(50./180.*np.pi)
vy0 = 30*np.sin(50./180.*np.pi)
v0= 30
x0 = 0
y0 = 0
t = np.arange(0., 200.+0.1,0.1)

result = odeint(derivative, np.array([v0,x0, y0]),t)
vx = result[:,0]
vy = result[:,2]

plt.plot(t,vx,label="velocity x-dimension")
plt.plot(t,vy,label="velocity y-dimension")
plt.xlabel("time (seconds)")
plt.ylabel("Velocity (m/s)")
plt.legend()
plt.show()

# %%
x = result[:,1]
y = result[:,3]

plt.plot(x, y)
plt.xlabel("displacement from x-axis")
plt.ylabel('displacement from y-axis')
plt.xlim(0,100)
plt.ylim(-5,25)
plt.title('Trajectory of the projectile')
plt.grid()
plt.show()

# %% [markdown]
# (b) Now create an interact object that uses sliders for the initial speed, terminal velocity, launch angle, and time. Have it plot two curves - one representing the solution with quadratic drag and the other in the absence of drag:

# %%
from IPython.html.widgets import interact, interactive 

def projectile(v0=30, vterm=44, th0=50*np.pi/180, time=200):
    g = 9.81 #m/s^2
    vx = v0 * np.cos(th0)
    x0 = 0
    vy = v0 *np.sin(th0)
    y0 = 1.5
    t = np.arange(0.,time+0.001,0.001)
    init = np.array([vx0,vy0,vterm])
    
    result = odeint(derivative, init, t)
    
    vx = result[:,0]
    vy = result[:,1]
    x = vx * t
    y = vy * t
    xt = x0 +vx*t
    yt = y0 +vy*t - .5*g*t**2
    
    plt.plot(x, y, label="w/ drag")
    plt.plot(xt, yt, label="w/out drag")
    plt.xlabel("displacement from x-axis")
    plt.ylabel('displacement from y-axis')
    plt.legend()
    plt.title('Trajectory of the projectile')
    plt.grid()
    plt.show()
    

v = interact(projectile, v0=(0,100,0.1),vterm=(0,110,1),th0=(0,180,1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
# ...
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-b91e34076a0d> in derivative(y, t)
#       6     m = 1 #kg
#       7
# ----> 8     y1 = y[3]
#       9     x1 = y[1]
#      10     dvxdt = -g/m * vx/vter**2 * sqrt(vx**2+vy**2)
#
# IndexError: index out of bounds
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
