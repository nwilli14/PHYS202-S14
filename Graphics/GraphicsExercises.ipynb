# %% [markdown]
# Graphics Exercises

# %%
# %pylab inline
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# 1. Have a look at the Matplotlib gallery, find a cool looking figure, use the %loadpy magic we used before to copy the code into the box below, and modify it. Note that some of the examples might require packages that are not installed on your machine (in particular those that make maps) - if this is the case, pick another example for the purposes of this exercise.
# Type %loadpy and then the URL of the py file containing the code, and it will automatically copy it into a cell below. Run the cell with the code to see the figure.

# %%
# %loadpy http://matplotlib.org/mpl_examples/lines_bars_and_markers/fill_demo.py

# %%
"""
Simple demo of the fill function.
"""
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0, 1)
y = np.sin(4 * np.pi * x) * np.exp(-5 * x)

plt.fill(x, y, 'r')
plt.grid(True)
plt.show()

# %% [markdown]
# 2 Download the linked file called sunspots.txt, which contains the observed number of sunspots on the Sun for each month since January 1749. The file contains two columns of numbers, the first being the month and the second being the sunspot number. (See note below∗ for how to download it.)

# %% [markdown]
# (a) Write some code that reads in the data and makes a graph of sunspots as a function of time. Format the x-axis labels to show every 25th year starting with 1750 e.g. (1750, 1775, 1800, 1825, 1850, etc.), instead of sunspot number. Be sure to think about how to make this graph publication quality, i.e. it should have labels, a legend, and customized (i.e. NOT default) color and data representation choices.

# %%
x = np.loadtxt('sunspots.txt', unpack=True)
spots = x[1]
months = x[0]
years = months / 12 + 1749
plt.plot(years, spots, color="green", linewidth=0, marker='d', label="sunspots")
plt.legend(loc='upper left')
plt.xlabel('year')
plt.ylabel('number of spots')
xlim([1750, 2025])
plt.xticks(arange(1750, 2025, 25))
# Out:
# ([<matplotlib.axis.XTick at 0x12cac898>,
#   <matplotlib.axis.XTick at 0x12134e48>,
#   <matplotlib.axis.XTick at 0x12a75a58>,
#   <matplotlib.axis.XTick at 0x12a754e0>,
#   <matplotlib.axis.XTick at 0x12a75898>,
#   <matplotlib.axis.XTick at 0x1395ddd8>,
#   <matplotlib.axis.XTick at 0x1395d198>,
#   <matplotlib.axis.XTick at 0x1395d128>,
#   <matplotlib.axis.XTick at 0x1395d400>,
#   <matplotlib.axis.XTick at 0x122ee358>,
#   <matplotlib.axis.XTick at 0x12a931d0>],
#  <a list of 11 Text xticklabel objects>)

# %% [markdown]
# (b) Now add code to calculate the running average of the data. Plot both the original data and the running average on the same graph, only over the range covered by the first 1000 data points.

# %%
totalspots = 0
average = 0
arrave = np.empty(spots.shape)
for i in range(len(spots)):
        totalspots += spots[i]
        average = totalspots/(months[i]+1)
        arrave[i] = average
print arrave
# Out:
# [ 58.          60.3         63.53333333 ...,  51.9432028   51.93415022
#   51.92449889]

# %%
plt.plot(years, spots, color="green", linewidth=0, marker='d', label="sunspots")
plt.plot(years, arrave, color="black", linewidth=4, label="average")
plt.legend(loc="upper left")
xlim([1750, 2025])
plt.xticks(arange(1750, 2025, 25))
fig, ax1 = plt.subplots(1, 1)
ax1.set_xlim([0, 1000])
# Out:
# (0, 1000)

# %% [markdown]
# 3 Download the linked file called stars.txt, which contains the temperatures and magnitudes of several thousand stars in the Milky Way near our solar system. You will use this data to construct a scatter plot of stellar magnitude (logarithm of brightness) vs. temperature (in Kelvin), called a Hertzsprung-Russell diagram, after the astronomers who first plotted such data this way. The diagram is one of the fundamental tools of stellar astrophysics. For historical reasons, H-R diagrams are normally plotted with both the magnitude and temperature axes decreasing to the right/up rather than increasing.

# %% [markdown]
# (a) Read in the data from stars.txt and plot the data as is, with magnitude and temperature increasing in the usual way. Add labels and format your graph as publication quality.

# %%
y = np.loadtxt('stars.txt', unpack=True)
bright = y[1]
temp = y[0]
plt.plot(temp, bright, color="blue", linewidth=0, marker='d', label="stars")
plt.xlabel('brightness')
plt.ylabel('Temperature (K)')
plt.legend(loc="upper right")

# %% [markdown]
# (b) Now use the xlim() and ylim() commands to flip your graph so that it is a correct H-R diagram. There are several regions of the diagram where stars seem to cluster. Have a look at the wikipedia entry on H-R diagrams to find out what each of these regions are called and add some annotations to your graph to identify them.

# %%
y = np.loadtxt('stars.txt', unpack=True)
bright = y[1]
temp = y[0]
plt.plot(temp, bright, color="red", linewidth=0, marker='*', label="stars")
plt.xlabel('brightness')
plt.ylabel('Temperature (K)')
plt.legend(loc="lower left")
ylim(20, -5)
xlim(16000, 0)
label = annotate('Main Squence', xy=(3000, 11))
label2 = annotate('White Dwarfs', xy=(8000, 17))
label3 = annotate('Giants', xy=(4500, -2))

# %% [markdown]
# 4 Make a 3D plot of the function G(x,y)=e(−x2−y2) over the range -6 <(x,y)< 6 using 51 bins in x and 51 bins in y.

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X = np.arange(-6, 6)
Y = np.arange(-6, 6)
Z = np.e**(-X**2 + -Y**2)
hist, xedges, yedges = np.histogram2d(X, Y, bins=51)

elements = (len(X) - 1) * (len(Y) - 1)
xpos, ypos = np.meshgrid(X, Y)

xpos = xpos.flatten()
ypos = ypos.flatten()
zpos = np.zeros(elements)
dx = 0.5 * np.ones_like(zpos)
dy = dx.copy()
dz = hist.flatten()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='b', zsort='average')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-d4a4fbfc2bfb> in <module>()
#      20 dz = hist.flatten()
#      21
# ---> 22 ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='b', zsort='average')
#      23
#      24 plt.show()
#
# C:\Users\Nick the Wizard\Anaconda\lib\site-packages\mpl_toolkits\mplot3d\axes3d.pyc in bar3d(self, x, y, z, dx, dy, dz, color, zsort, *args, **kwargs)
#    2352
#    2353         normals = self._generate_normals(polys)
# -> 2354         sfacecolors = self._shade_colors(facecolors, normals)
#    2355         col = art3d.Poly3DCollection(polys,
#    2356                                      zsort=zsort,
#
# C:\Users\Nick the Wizard\Anaconda\lib\site-packages\mpl_toolkits\mplot3d\axes3d.pyc in _shade_colors(self, color, normals)
#    1681             # colors should have final shape of (M, 4)
#    1682             alpha = color[:, 3]
# -> 1683             colors = (0.5 + norm(shade)[:, np.newaxis] * 0.5) * color
#    1684             colors[:, 3] = alpha
#    1685         else:
#
# C:\Users\Nick the Wizard\Anaconda\lib\site-packages\numpy\ma\core.pyc in __mul__(self, other)
#    3705     def __mul__(self, other):
#    3706         "Multiply other by self, and return a new masked array."
# -> 3707         return multiply(self, other)
#    3708     #
#    3709     def __rmul__(self, other):
#
# C:\Users\Nick the Wizard\Anaconda\lib\site-packages\numpy\ma\core.pyc in __call__(self, a, b, *args, **kwargs)
#     930         with np.errstate():
#     931             np.seterr(divide='ignore', invalid='ignore')
# --> 932             result = self.f(da, db, *args, **kwargs)
#     933         # check it worked
#     934         if result is NotImplemented:
#
# ValueError: operands could not be broadcast together with shapes (726,1) (864,4)

# %% [markdown]
# 5 Determine the electric potential for a quadrupole consisting of
#
# q1 = -1.0 nC at (-2 m, 0 m)
#
# q2 = -1.0 nC at (+2 m, 0 m)
#
# q3 = +1.0 nC at (0 m, -2 m)
#
# q4 = +1.0 nC at (0 m, +2 m)

# %% [markdown]
# (a) Make a surface plot on the range -4 <(x,y)< 4 using 101 bins in x and 101 bins in y. In this case, do not let k = q = d = 1. Use dimensionful quantities and compute the value of the potential in volts.
# Recall k = 8.9875517873681764 × 109 N⋅ m2/C2.

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-4, 4, 101)
y = np.linspace(-4, 4, 101)
x, y = np.meshgrid(x, y)

#make the function, V(x,y)
k = 8.9875517873681764e9 ; q = 1e-9; d = 2
V=(k*q/(x**2+(y-d)**2)**(0.5)) + (k*q/(x**2+(y+d)**2)**(0.5)) - (k*q/((x-d)**2+y**2)**(0.5)) - (k*q/((x+d)**2+y**2)**(0.5))

#To use 3D graphics in matplotlib, we first need to create an axes instance of the class Axes3D. 
#3D axes can be added to a matplotlib figure canvas in exactly the same way as 2D axes, but a 
#convenient way to create a 3D axis instance is to use the projection='3d' keyword argument to 
#the add_axes or add_subplot functions.

fig = plt.figure()

#Call the "get current axis" method on the figure object and set the projection to 3D
ax = fig.gca(projection='3d')
p = ax.plot_surface(x, y, V, rstride=1, cstride=1,linewidth=0, cmap=cm.coolwarm)

#To understand what the arguments to the plotting function do, try calling the help: 
#help(Axes3D.plot surface). In particular, investigate the colormap option. You can 
#also add a color bar to represent the value of the potential at each space point (x, y)
cb = fig.colorbar(p, shrink=0.5)

xlabel("x")
ylabel("y")

#show()
plt.show()

# %% [markdown]
# I dont know why the color is blue rather that a heat map blue to red scale....

# %% [markdown]
# (b) Now make a contour plot of the same data, with appropriate contour levels to see the shape of the potential.

# %% [markdown]
# 6 Find a juicy equation in a textbook from one of your classes and use LATEX to typeset it in a markdown cell. Include an explanation of what the equation is for.

# %% [markdown]
# \begin{equation}
# \frac{d^2\psi(x)}{dx^2} = \frac{2m}{\hbar}(U(x) - E)\psi(x)
# \end{equation}

# %% [markdown]
# The Schrodinger Equation
#
# used to determine the probiblity of a partical being observed in a partular location
